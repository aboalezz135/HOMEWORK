# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, confusion_matrix

# 1. استيراد البيانات وتحليلها
# إنشاء بيانات افتراضية
data = pd.DataFrame({
    'Feature1': np.random.randn(100),
    'Feature2': np.random.randn(100),
    'Target': np.random.randint(0, 2, size=100)
})

# عرض أول 5 صفوف من البيانات
print(data.head())

# تحليل إحصائي
print(data.describe())

# 2. تصور البيانات
# رسم توزيع المتغيرات باستخدام Seaborn
sns.pairplot(data, hue='Target')
plt.show()

# رسم بياني باستخدام Matplotlib
plt.hist(data['Feature1'], bins=10, alpha=0.5, label='Feature1')
plt.hist(data['Feature2'], bins=10, alpha=0.5, label='Feature2')
plt.legend(loc='upper right')
plt.title('Distribution of Features')
plt.show()

# 3. بناء وتدريب نموذج تعلم آلي باستخدام scikit-learn
# فصل الميزات عن الهدف
X = data[['Feature1', 'Feature2']]
y = data['Target']

# تقسيم البيانات إلى مجموعة تدريب ومجموعة اختبار
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# بناء نموذج شجرة القرار
model = DecisionTreeClassifier()

# تدريب النموذج
model.fit(X_train, y_train)

# التنبؤ على مجموعة الاختبار
y_pred = model.predict(X_test)

# تقييم النموذج
print('Confusion Matrix:')
print(confusion_matrix(y_test, y_pred))

print('\nClassification Report:')
print(classification_report(y_test, y_pred))
# Out:
#    Feature1  Feature2  Target
# 0  1.959360  0.026665       1
# 1  0.100075  0.004927       0
# 2 -0.430022  2.451316       0
# 3 -1.565812 -0.508934       0
# 4  0.926722  0.271873       0
#          Feature1    Feature2      Target
# count  100.000000  100.000000  100.000000
# mean    -0.117847    0.115601    0.480000
# std      0.960133    0.993494    0.502117
# min     -2.148506   -1.953877    0.000000
# 25%     -0.784794   -0.526138    0.000000
# 50%     -0.093872    0.075091    0.000000
# 75%      0.583774    0.769996    1.000000
# max      1.981986    2.451822    1.000000
# C:\Users\USERW\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...
